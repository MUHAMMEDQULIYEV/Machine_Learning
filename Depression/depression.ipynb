# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
dep=pd.read_csv("depression_data.csv.zip",compression="zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dep=pd.read_csv("depression_data.csv.zip",compression="zip")
#
# File ~/anaconda3/envs/ai/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
dep.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# ...

# %%
dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413768 entries, 0 to 413767
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name                          413768 non-null  object
#  1   Age                           413768 non-null  int64
#  2   Marital Status                413768 non-null  object
#  3   Education Level               413768 non-null  object
#  4   Number of Children            413768 non-null  int64
#  5   Smoking Status                413768 non-null  object
#  6   Physical Activity Level       413768 non-null  object
#  7   Employment Status             413768 non-null  object
#  8   Income                        413768 non-null  float64
#  9   Alcohol Consumption           413768 non-null  object
#  10  Dietary Habits                413768 non-null  object
#  11  Sleep Patterns                413768 non-null  object
# ...

# %%
dep.tail()
# Out:
#                    Name  Age Marital Status    Education Level  \
# 413763      Sean Miller   68        Married    Master's Degree
# 413764  Christina Brown   26         Single  Bachelor's Degree
# 413765  Matthew Jenkins   57        Married  Bachelor's Degree
# 413766    Gary Faulkner   71        Married   Associate Degree
# 413767   Joseph Johnson   62        Widowed    Master's Degree
#
#         Number of Children Smoking Status Physical Activity Level  \
# 413763                   0         Former                Moderate
# 413764                   0        Current                  Active
# 413765                   0     Non-smoker               Sedentary
# 413766                   2     Non-smoker               Sedentary
# 413767                   0         Former                Moderate
#
#        Employment Status     Income Alcohol Consumption Dietary Habits  \
# 413763          Employed  109233.43                 Low        Healthy
# ...

# %%
dep.index
# Out:
# RangeIndex(start=0, stop=413768, step=1)

# %%
dep.describe()
# Out:
#                  Age  Number of Children         Income
# count  413768.000000       413768.000000  413768.000000
# mean       49.000713            1.298972   50661.707971
# std        18.158759            1.237054   40624.100565
# min        18.000000            0.000000       0.410000
# 25%        33.000000            0.000000   21001.030000
# 50%        49.000000            1.000000   37520.135000
# 75%        65.000000            2.000000   76616.300000
# max        80.000000            4.000000  209995.220000

# %%
dep.isna().any()
# Out:
# Name                            False
# Age                             False
# Marital Status                  False
# Education Level                 False
# Number of Children              False
# Smoking Status                  False
# Physical Activity Level         False
# Employment Status               False
# Income                          False
# Alcohol Consumption             False
# Dietary Habits                  False
# Sleep Patterns                  False
# History of Mental Illness       False
# History of Substance Abuse      False
# Family History of Depression    False
# Chronic Medical Conditions      False
# dtype: bool

# %%
dep.groupby("Marital Status")["Sleep Patterns"].value_counts()
# Out:
# Marital Status  Sleep Patterns
# Divorced        Fair               16089
#                 Good               10388
#                 Poor                6252
# Married         Fair              112397
#                 Poor               92240
#                 Good               35807
# Single          Fair               33992
#                 Good               23376
#                 Poor               14742
# Widowed         Fair               34311
#                 Good               17826
#                 Poor               16348
# Name: count, dtype: int64

# %%
sns.heatmap(dep.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.histplot(dep,x="Age",y="Number of Children")
# Out:
# <Axes: xlabel='Age', ylabel='Number of Children'>

# %%
sns.pairplot(dep)

# %%
dep.isna().duplicated()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 413763     True
# 413764     True
# 413765     True
# 413766     True
# 413767     True
# Length: 413768, dtype: bool

# %%
dep.drop_duplicates(inplace=True)

# %%
sns.boxplot(dep,)
# Out:
# <Axes: >

# %%
sns.distplot(dep['Age'])
# Out:
# /tmp/ipykernel_40805/1812058509.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dep['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
dep['Age'].dtypes
# Out:
# dtype('int64')

# %%
dep.corr(numeric_only=True)
# Out:
#                          Age  Number of Children    Income
# Age                 1.000000            0.259268 -0.065628
# Number of Children  0.259268            1.000000  0.028737
# Income             -0.065628            0.028737  1.000000
