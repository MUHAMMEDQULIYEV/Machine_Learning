# %%
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#P_spam=np.random.rand()
P_spam=0.1

# %%
P_word_given_spam=0.8
P_word_given_ham=0.5
