# %%
import pandas as pd
import yfinance as yf
import seaborn as sns

# %%
import yfinance as yf

data = yf.download("RTY=F", period="1y")
print(data.head())
# Out:
# /tmp/ipykernel_59704/2778258330.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("RTY=F", period="1y")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open  Volume
# Ticker            RTY=F        RTY=F        RTY=F        RTY=F   RTY=F
# Date
# 2024-12-12  2365.500000  2400.399902  2363.100098  2399.100098  160456
# 2024-12-13  2349.699951  2373.000000  2337.300049  2366.199951  260615
# 2024-12-16  2363.100098  2374.500000  2341.500000  2346.500000  387638
# 2024-12-17  2335.300049  2366.000000  2330.800049  2362.199951  177723
# 2024-12-18  2231.800049  2358.000000  2211.500000  2333.899902  113310

# %%
data
# Out:
# Price             Close         High          Low         Open  Volume
# Ticker            RTY=F        RTY=F        RTY=F        RTY=F   RTY=F
# Date
# 2024-12-12  2365.500000  2400.399902  2363.100098  2399.100098  160456
# 2024-12-13  2349.699951  2373.000000  2337.300049  2366.199951  260615
# 2024-12-16  2363.100098  2374.500000  2341.500000  2346.500000  387638
# 2024-12-17  2335.300049  2366.000000  2330.800049  2362.199951  177723
# 2024-12-18  2231.800049  2358.000000  2211.500000  2333.899902  113310
# ...                 ...          ...          ...          ...     ...
# 2025-12-08  2525.100098  2545.800049  2518.000000  2528.000000  145613
# 2025-12-09  2529.399902  2545.699951  2516.600098  2522.899902  154778
# 2025-12-10  2563.899902  2581.800049  2519.699951  2530.300049  222045
# 2025-12-11  2593.199951  2598.699951  2543.399902  2570.500000  222045
# 2025-12-12  2600.800049  2605.000000  2594.199951  2598.899902    4952
#
# [253 rows x 5 columns]

# %%
sns.pairplot(data)

# %%
sns.kdeplot(data=data,x=('Close', 'RTY=F'))
# Out:
# <Axes: xlabel="('Close', 'RTY=F')", ylabel='Density'>
